# %% [markdown]
# LaRutaDelPanda1

# %% [markdown]
# #0. IMPORTAR LIBRERIA

# %%
#IMPORTAR LIBRERIA
import pandas as pd

# %% [markdown]
# #1. SERIE Y DATAFRAME

# %%
#CREAR SERIE
serie = pd.Series([1,2,3],index=['A','B','C'],name='Col1')
serie
# Out:
# A    1
# B    2
# C    3
# Name: Col1, dtype: int64

# %%
#CREAR DATAFRAME (forma 1)
datos = [[1,4],[2,5],[3,6]]
index=['A','B','C']
columns=['Col1','Col2']

dataframe = pd.DataFrame(data=datos,index=index,columns=columns)
dataframe
# Out:
#    Col1  Col2
# A     1     4
# B     2     5
# C     3     6

# %%
#CREAR DATAFRAME (forma 2)
dataframe2 = pd.DataFrame(data =[[1,7],[8,9]],index=['B','D'],columns=['Col1','Col3'])
dataframe2
# Out:
#    Col1  Col3
# B     1     7
# D     8     9

# %%
#CREAR DATAFRAME (forma 3)
dataframe3 = pd.DataFrame({'Nombre':['Luka','Lebron','Kevin','Karl'],
                           'FechaNace':['2/2/90','26/3/91','25/06/20','29/06/21'],
                           'Id':['A101','A154','A170','A197']})
dataframe3
# Out:
#    Nombre FechaNace    Id
# 0    Luka    2/2/90  A101
# 1  Lebron   26/3/91  A154
# 2   Kevin  25/06/20  A170
# 3    Karl  29/06/21  A197

# %%
#CREAR COPIA AL DATAFRAME
dataframe4 = dataframe.copy()
dataframe4
# Out:
#    Col1  Col2
# A     1     4
# B     2     5
# C     3     6

# %% [markdown]
# #2. SELECCIONAR REGISTROS, COLUMNAS Y FILAS

# %%
#REGISTROS: SELECCIONAR LOS PRIMEROS REGISTROS
dataframe.head(2)
# Out:
#    Col1  Col2
# A     1     4
# B     2     5

# %%
#REGISTROS: SELECCIONAR LOS ULTIMOS REGISTROS
dataframe.tail(2)
# Out:
#    Col1  Col2
# B     2     5
# C     3     6

# %%
#COLUMNAS: SELECCIONAR 1
dataframe['Col1']
#dataframe.Col1
# Out:
# A    1
# B    2
# C    3
# Name: Col1, dtype: int64

# %%
#COLUMNAS: SELECCIONAR MAS DE 1
dataframe[['Col1','Col2']]
# Out:
#    Col1  Col2
# A     1     4
# B     2     5
# C     3     6

# %%
#FILAS: SELECCIONAR 1. LOCALIZAR POR NOMBRE DE INDEX
dataframe.loc['A']
# Out:
# Col1    1
# Col2    4
# Name: A, dtype: int64

# %%
#FILAS: SELECCIONAR MAS DE 1. LOCALIZAR POR NOMBRE DE INDEX
dataframe.loc[['A','B']]
# Out:
#    Col1  Col2
# A     1     4
# B     2     5

# %%
#FILAS: SELECCIONAR 1. LOCALIZAR POR POSICION DE INDEX
dataframe.iloc[0]
# Out:
# Col1    1
# Col2    4
# Name: A, dtype: int64

# %%
#FILAS: SELECCIONAR MAS DE 1. LOCALIZAR POR POSICION DE INDEX
dataframe.iloc[1:]
# Out:
#    Col1  Col2
# B     2     5
# C     3     6

# %% [markdown]
# #3. REVISAR Y ENTENDER DATAFRAME

# %%
#INFORMACION BASE
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, A to C
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Col1    3 non-null      int64
#  1   Col2    3 non-null      int64
# dtypes: int64(2)
# memory usage: 180.0+ bytes

# %%
dataframe.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, A to C
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Col1    3 non-null      int64
#  1   Col2    3 non-null      int64
# dtypes: int64(2)
# memory usage: 330.0 bytes

# %%
#DIMENSIONES
dataframe.shape
# Out:
# (3, 2)

# %%
#DESCRIPCION ESTADISTICA
dataframe.describe()
# Out:
#        Col1  Col2
# count   3.0   3.0
# mean    2.0   5.0
# std     1.0   1.0
# min     1.0   4.0
# 25%     1.5   4.5
# 50%     2.0   5.0
# 75%     2.5   5.5
# max     3.0   6.0

# %%
#VER NOMBRES DE FILAS
dataframe.index
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
#VER NOMBRES DE COLUMNAS
dataframe.columns
# Out:
# Index(['Col1', 'Col2'], dtype='object')

# %%
#VER TIPO DE DATO DE LAS COLUMNAS
dataframe.dtypes
# Out:
# Col1    int64
# Col2    int64
# dtype: object

# %%
#VER COLUMNAS CON DATO NUMERICO
dataframe._get_numeric_data()
# Out:
#    Col1  Col2
# A     1     4
# B     2     5
# C     3     6

# %%
#REVISAR Y ENTENDER CODIGO
#dataframe.sample(2)

# %%
#FILTRAR DATOS POR VALOR EN COLUMNA
dataframe[dataframe['Col1']>1]
# Out:
#    Col1  Col2
# B     2     5
# C     3     6

# %%
#ORDENAR DATOS POR VALOR EN COLUMNA
dataframe.sort_values(['Col2'],ascending=False)
# Out:
#    Col1  Col2
# C     3     6
# B     2     5
# A     1     4

# %%
#IDENTIFICAR REGISTROS UNICOS EN COLUMNA
dataframe['Col1'].unique()
# Out:
# array([1, 2, 3])

# %%
#IDENTIFICAR REGISTROS DUPLICADOS EN COLUMNA
dataframe['Col1'].duplicated()
# Out:
# A    False
# B    False
# C    False
# Name: Col1, dtype: bool

# %%
#IDENTIFICAR REGISTROS NULOS EN COLUMNA
dataframe.isnull()
#dataframe.isna()
# Out:
#     Col1   Col2
# A  False  False
# B  False  False
# C  False  False

# %%
#IDENTIFICAR REGISTROS NO NULOS EN COLUMNA
dataframe.notna()
# Out:
#    Col1  Col2
# A  True  True
# B  True  True
# C  True  True

# %% [markdown]
# #4. TRANSFORMAR DATAFRAME

# %%
#REVISAR Y ENTENDER CODIGO
#RESETEAR INDEX
#dataframe4 = dataframe.reset_index(inplace=True)
#dataframe4

# %%
#REVISAR Y ENTENDER CODIGO
#RENOMBRE COLUMNAS
#dataframe5 = dataframe.rename()
#dataframe5

# %%
#CAMBIAR TIPO DE DATO DE COLUMNA
dataframe6 = dataframe.astype(dtype='float32')
dataframe6.dtypes
# Out:
# Col1    float32
# Col2    float32
# dtype: object

# %%
#REVISAR Y ENTENDER CODIGO (INSERTAR ATRIBUTOS STRING PARA PROBAR CODIGO)
#REEMPLAZAR COLUMNAS STR
#dataframe7 = dataframe.str.replace()
#dataframe7

# %%
#TRANSPONER FILAS Y COLUMNAS
#dataframe8 = dataframe.transpose()
dataframe8 = dataframe.T
dataframe8
# Out:
#       A  B  C
# Col1  1  2  3
# Col2  4  5  6

# %%
#BORRAR COLUMNA
dataframe9 = dataframe.drop('Col1',axis=1)
dataframe9
# Out:
#    Col2
# A     4
# B     5
# C     6

# %%
#BORRAR FILA
dataframe10 = dataframe.drop('A',axis=0)
dataframe10
# Out:
#    Col1  Col2
# B     2     5
# C     3     6

# %%
#BORRAR NULOS DE COLUMNA
dataframe11 = dataframe.dropna()
dataframe11
# Out:
#    Col1  Col2
# A     1     4
# B     2     5
# C     3     6

# %%
#REVISAR Y ENTENDER CODIGO
#RELLENAR NULOS DE COLUMNA
#dataframe12 = dataframe.fillna()
#dataframe12

# %%
#BORRAR DUPLICADOS DE COLUMNA
dataframe13 = dataframe.drop_duplicates()
dataframe13
# Out:
#    Col1  Col2
# A     1     4
# B     2     5
# C     3     6

# %%
#ALTERAR REGISTROS
dataframe14 = dataframe + 5
dataframe14
# Out:
#    Col1  Col2
# A     6     9
# B     7    10
# C     8    11

# %%
#CONCATENAR DATAFRAME
dataframe15 = pd.concat([dataframe,dataframe14])
dataframe15
# Out:
#    Col1  Col2
# A     1     4
# B     2     5
# C     3     6
# A     6     9
# B     7    10
# C     8    11

# %%
#INNER JOIN
dataframe16 = dataframe.merge(dataframe2)
dataframe16
# Out:
#    Col1  Col2  Col3
# 0     1     4     7

# %%
#LEFT JOIN
dataframe17 = dataframe.merge(dataframe2,how='left')
dataframe17
# Out:
#    Col1  Col2  Col3
# 0     1     4   7.0
# 1     2     5   NaN
# 2     3     6   NaN

# %%
#RIGHT JOIN
dataframe18 = dataframe.merge(dataframe2,how='right')
dataframe18
# Out:
#    Col1  Col2  Col3
# 0     1   4.0     7
# 1     8   NaN     9

# %%
#OUTER JOIN
dataframe19 = dataframe.merge(dataframe2,how='outer')
dataframe19
# Out:
#    Col1  Col2  Col3
# 0     1   4.0   7.0
# 1     2   5.0   NaN
# 2     3   6.0   NaN
# 3     8   NaN   9.0

# %%
#UNIR FILAS POR COINCIDENCIA DE INDEX
dataframe20 = dataframe.merge(dataframe2,left_index=True,right_index=True)
dataframe20
# Out:
#    Col1_x  Col2  Col1_y  Col3
# B       2     5       1     7

# %% [markdown]
# #5. OPERAR DATAFRAME

# %%
#SUM/PROMEDIO/MAX/MIN DE UNA COLUMNA
dataframe['Col1'].sum()
#dataframe['Col1'].mean()
#dataframe['Col1'].max()
#dataframe['Col1'].min()
# Out:
# 6

# %%
#CONTAR VALORES UNICOS DE UNA COLUMNA
dataframe[['Col1']].value_counts()
# Out:
# Col1
# 1       1
# 2       1
# 3       1
# Name: count, dtype: int64
